# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import sys
from datetime import datetime
import requests

# Importing the API key for the weather
# sys.path.append('C:/Users/manny/Documents/Manny Data Analytics BootCamp/Manny Berkeley Class/Weather Analysis Project/PlanMyTrip/')
from configuration import weather_api_key

# %%
# Generating 2000 random values for the longitude and the latitude
lat = np.random.uniform(-90,90,2000)
lng = np.random.uniform(-180,180,2000)

# Zipping the longitude and latitude arrays
lat_lng = zip(lat,lng)

# converting the zip to a list
coordinates = list(lat_lng)

# %%
# Creating an empty list for cities
cities = []

for coord in coordinates:
    city = citipy.nearest_city(coord[0],coord[1]).city_name

    # Check for duplicates
    if city not in cities:
        cities.append(city)

# %%
# Parameters for the request
# params = {
#     'q': cities[-4],
#     'appid': weather_api_key
# }
# # Build the url
# url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial'

# requests.get(url=url,params=params).json()

# %%
# Build the url
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial'

# Parameters for the request
params = {
    'q': '',
    'appid': weather_api_key
}

# Create an empty list to store the information that will be captured
city_data = []

# Print the beginning of the logging process
print('Beginning the data retrieval')
print('****************************')

record_count = 1
set_count = 1

for index, city in enumerate(cities):
    params['q'] = city

    if index % 100 == 0 and index >= 100:
        set_count += 1
        record_count = 1

    # Logging the URL, record number, set number and city
    print(f'Processing record {record_count} of Set {set_count} | {city}')
    record_count += 1

    try:
        city_weather = requests.get(url=base_url,params=params).json()
        # city_data.append(city_weather['coord']['lat'])
        city_data.append({
            'City': city.title(),
            'Lat': city_weather['coord']['lat'],
            'Lng': city_weather['coord']['lon'],
            'Humidity': city_weather['main']['humidity'],
            'Cloudiness': city_weather['clouds']['all'],
            'Max Temp': city_weather['main']['temp_max'],
            'Wind Speed': city_weather['wind']['speed'],
            'Country': city_weather['sys']['country'],
            'Current Description': city_weather['weather'][0]['description']
        })
    except:
        print(f'City {city} not found. Skipping..............')

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning the data retrieval
# ****************************
# Processing record 1 of Set 1 | punta arenas
# Processing record 2 of Set 1 | butaritari
# Processing record 3 of Set 1 | cape town
# Processing record 4 of Set 1 | goderich
# Processing record 5 of Set 1 | hilo
# Processing record 6 of Set 1 | lavrentiya
# Processing record 7 of Set 1 | thompson
# Processing record 8 of Set 1 | narwar
# Processing record 9 of Set 1 | yishui
# Processing record 10 of Set 1 | glendive
# Processing record 11 of Set 1 | samusu
# City samusu not found. Skipping..............
# Processing record 12 of Set 1 | constitucion
# Processing record 13 of Set 1 | ushuaia
# Processing record 14 of Set 1 | dikson
# Processing record 15 of Set 1 | tiksi
# Processing record 16 of Set 1 | saldanha
# Processing record 17 of Set 1 | port macquarie
# Processing record 18 of Set 1 | zhigansk
# Processing record 19 of Set 1 | tambura
# Processing record 20 of Set 1 | mataura
# Processing record 21 of Set 1 | ribeira grande
# Processing record 22 of Set 1 | kapaa
# Processing record 23 of Set 1 | port alfred
# Processing record 24 of Set 1 | jamuria
# Processing record 25 of Set 1 | arraial do cabo
# Processing record 26 of Set 1 | watrous
# Processing record 27 of Set 1 | atuona
# Processing record 28 of Set 1 | kirakira
# Processing record 29 of Set 1 | longyearbyen
# Processing record 30 of Set 1 | hofn
# Processing record 31 of Set 1 | klaksvik
# Processing record 32 of Set 1 | jalu
# Processing record 33 of Set 1 | tessalit
# Processing record 34 of Set 1 | rikitea
# Processing record 35 of Set 1 | meulaboh
# Processing record 36 of Set 1 | cap-aux-meules
# Processing record 37 of Set 1 | camacari
# Processing record 38 of Set 1 | tuktoyaktuk
# Processing record 39 of Set 1 | gombong
# Processing record 40 of Set 1 | jamestown
# Processing record 41 of Set 1 | geraldton
# Processing record 42 of Set 1 | bengkulu
# Processing record 43 of Set 1 | oksfjord
# Processing record 44 of Set 1 | hermanus
# Processing record 45 of Set 1 | del rio
# Processing record 46 of Set 1 | sao filipe
# Processing record 47 of Set 1 | sentyabrskiy
# City sentyabrskiy not found. Skipping..............
# Processing record 48 of Set 1 | port elizabeth
# Processing record 49 of Set 1 | souillac
# Processing record 50 of Set 1 | amahai
# Processing record 51 of Set 1 | narsaq
# Processing record 52 of Set 1 | jacareacanga
# Processing record 53 of Set 1 | kavieng
# Processing record 54 of Set 1 | ha tinh
# Processing record 55 of Set 1 | severo-kurilsk
# Processing record 56 of Set 1 | katsuura
# Processing record 57 of Set 1 | polovinnoye
# Processing record 58 of Set 1 | saint-augustin
# Processing record 59 of Set 1 | aloleng
# Processing record 60 of Set 1 | belushya guba
# City belushya guba not found. Skipping..............
# Processing record 61 of Set 1 | viedma
# Processing record 62 of Set 1 | albany
# Processing record 63 of Set 1 | prince rupert
# Processing record 64 of Set 1 | puerto leguizamo
# Processing record 65 of Set 1 | sechura
# Processing record 66 of Set 1 | qaanaaq
# Processing record 67 of Set 1 | vaini
# Processing record 68 of Set 1 | bredasdorp
# Processing record 69 of Set 1 | mount gambier
# Processing record 70 of Set 1 | hami
# Processing record 71 of Set 1 | hurghada
# Processing record 72 of Set 1 | colares
# Processing record 73 of Set 1 | yellowknife
# Processing record 74 of Set 1 | barrow
# Processing record 75 of Set 1 | ilulissat
# Processing record 76 of Set 1 | san quintin
# Processing record 77 of Set 1 | pangnirtung
# Processing record 78 of Set 1 | new norfolk
# Processing record 79 of Set 1 | provideniya
# Processing record 80 of Set 1 | busselton
# Processing record 81 of Set 1 | hithadhoo
# Processing record 82 of Set 1 | bodden town
# Processing record 83 of Set 1 | sao joao da barra
# Processing record 84 of Set 1 | udachnyy
# Processing record 85 of Set 1 | mbanza-ngungu
# Processing record 86 of Set 1 | mildura
# Processing record 87 of Set 1 | taolanaro
# City taolanaro not found. Skipping..............
# Processing record 88 of Set 1 | japura
# Processing record 89 of Set 1 | osmena
# Processing record 90 of Set 1 | north bend
# Processing record 91 of Set 1 | labutta
# City labutta not found. Skipping..............
# Processing record 92 of Set 1 | poum
# Processing record 93 of Set 1 | yomitan
# City yomitan not found. Skipping..............
# Processing record 94 of Set 1 | nikolskoye
# Processing record 95 of Set 1 | kungurtug
# Processing record 96 of Set 1 | aldan
# Processing record 97 of Set 1 | chernyshevskiy
# Processing record 98 of Set 1 | hobart
# Processing record 99 of Set 1 | basoko
# Processing record 100 of Set 1 | pinega
# Processing record 1 of Set 2 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping..............
# Processing record 2 of Set 2 | nemuro
# Processing record 3 of Set 2 | faanui
# Processing record 4 of Set 2 | parauna
# Processing record 5 of Set 2 | ahipara
# Processing record 6 of Set 2 | yerbogachen
# Processing record 7 of Set 2 | tura
# Processing record 8 of Set 2 | kodiak
# Processing record 9 of Set 2 | nanortalik
# Processing record 10 of Set 2 | khovu-aksy
# Processing record 11 of Set 2 | bluff
# Processing record 12 of Set 2 | sarangani
# Processing record 13 of Set 2 | massakory
# Processing record 14 of Set 2 | puerto suarez
# Processing record 15 of Set 2 | mareeba
# Processing record 16 of Set 2 | umzimvubu
# City umzimvubu not found. Skipping..............
# Processing record 17 of Set 2 | lakatoro
# Processing record 18 of Set 2 | sao joao de pirabas
# Processing record 19 of Set 2 | mar del plata
# Processing record 20 of Set 2 | norman wells
# Processing record 21 of Set 2 | barentsburg
# City barentsburg not found. Skipping..............
# Processing record 22 of Set 2 | marcona
# City marcona not found. Skipping..............
# Processing record 23 of Set 2 | chuy
# Processing record 24 of Set 2 | puerto ayora
# Processing record 25 of Set 2 | hadejia
# Processing record 26 of Set 2 | tasiilaq
# Processing record 27 of Set 2 | chebsara
# Processing record 28 of Set 2 | kaitangata
# Processing record 29 of Set 2 | kimberley
# Processing record 30 of Set 2 | stoyba
# City stoyba not found. Skipping..............
# Processing record 31 of Set 2 | astana
# Processing record 32 of Set 2 | san patricio
# Processing record 33 of Set 2 | lebu
# Processing record 34 of Set 2 | zyryanka
# Processing record 35 of Set 2 | esperance
# Processing record 36 of Set 2 | batamshinskiy
# Processing record 37 of Set 2 | georgetown
# Processing record 38 of Set 2 | flinders
# Processing record 39 of Set 2 | sobolevo
# Processing record 40 of Set 2 | saskylakh
# Processing record 41 of Set 2 | dhidhdhoo
# Processing record 42 of Set 2 | bolungarvik
# City bolungarvik not found. Skipping..............
# Processing record 43 of Set 2 | marzuq
# Processing record 44 of Set 2 | karaton
# Processing record 45 of Set 2 | benemerito de las americas
# Processing record 46 of Set 2 | amderma
# City amderma not found. Skipping..............
# Processing record 47 of Set 2 | dibaya
# City dibaya not found. Skipping..............
# Processing record 48 of Set 2 | hualmay
# Processing record 49 of Set 2 | arlit
# Processing record 50 of Set 2 | haines junction
# Processing record 51 of Set 2 | fortuna
# Processing record 52 of Set 2 | agadez
# Processing record 53 of Set 2 | benghazi
# Processing record 54 of Set 2 | lasa
# Processing record 55 of Set 2 | tazovskiy
# Processing record 56 of Set 2 | coos bay
# Processing record 57 of Set 2 | misratah
# Processing record 58 of Set 2 | wheeling
# Processing record 59 of Set 2 | pevek
# Processing record 60 of Set 2 | khatanga
# Processing record 61 of Set 2 | dinagat
# Processing record 62 of Set 2 | avarua
# Processing record 63 of Set 2 | tabiauea
# City tabiauea not found. Skipping..............
# Processing record 64 of Set 2 | ambilobe
# Processing record 65 of Set 2 | durango
# Processing record 66 of Set 2 | coari
# Processing record 67 of Set 2 | deputatskiy
# Processing record 68 of Set 2 | wajir
# Processing record 69 of Set 2 | bethel
# Processing record 70 of Set 2 | shahreza
# Processing record 71 of Set 2 | rapar
# Processing record 72 of Set 2 | upernavik
# Processing record 73 of Set 2 | cocachacra
# Processing record 74 of Set 2 | burnie
# Processing record 75 of Set 2 | pisco
# Processing record 76 of Set 2 | castro
# Processing record 77 of Set 2 | mattru
# Processing record 78 of Set 2 | huarmey
# Processing record 79 of Set 2 | vytegra
# Processing record 80 of Set 2 | tomohon
# Processing record 81 of Set 2 | vila franca do campo
# Processing record 82 of Set 2 | broome
# Processing record 83 of Set 2 | neman
# Processing record 84 of Set 2 | kloulklubed
# Processing record 85 of Set 2 | lambarene
# Processing record 86 of Set 2 | wangqing
# Processing record 87 of Set 2 | moss point
# Processing record 88 of Set 2 | dicabisagan
# Processing record 89 of Set 2 | shieli
# Processing record 90 of Set 2 | yatou
# Processing record 91 of Set 2 | college
# Processing record 92 of Set 2 | hinton
# Processing record 93 of Set 2 | verkhnyaya inta
# Processing record 94 of Set 2 | menongue
# Processing record 95 of Set 2 | arman
# Processing record 96 of Set 2 | victoria
# Processing record 97 of Set 2 | carnarvon
# Processing record 98 of Set 2 | saleaula
# City saleaula not found. Skipping..............
# Processing record 99 of Set 2 | eirunepe
# Processing record 100 of Set 2 | tselina
# Processing record 1 of Set 3 | saint george
# Processing record 2 of Set 3 | ocos
# Processing record 3 of Set 3 | ortona
# Processing record 4 of Set 3 | komsomolskiy
# Processing record 5 of Set 3 | abha
# Processing record 6 of Set 3 | nioro
# Processing record 7 of Set 3 | dondo
# Processing record 8 of Set 3 | zaozerne
# Processing record 9 of Set 3 | nouadhibou
# Processing record 10 of Set 3 | cockburn town
# Processing record 11 of Set 3 | cidreira
# Processing record 12 of Set 3 | mali
# Processing record 13 of Set 3 | lompoc
# Processing record 14 of Set 3 | eureka
# Processing record 15 of Set 3 | dumai
# Processing record 16 of Set 3 | umm kaddadah
# Processing record 17 of Set 3 | kutum
# Processing record 18 of Set 3 | tabuk
# Processing record 19 of Set 3 | karratha
# Processing record 20 of Set 3 | chokurdakh
# Processing record 21 of Set 3 | liyang
# Processing record 22 of Set 3 | iqaluit
# Processing record 23 of Set 3 | walvis bay
# Processing record 24 of Set 3 | qaqortoq
# Processing record 25 of Set 3 | anadyr
# Processing record 26 of Set 3 | hokitika
# Processing record 27 of Set 3 | quelimane
# Processing record 28 of Set 3 | coihaique
# Processing record 29 of Set 3 | gat
# Processing record 30 of Set 3 | anori
# Processing record 31 of Set 3 | caramay
# Processing record 32 of Set 3 | bay roberts
# Processing record 33 of Set 3 | coahuayana
# Processing record 34 of Set 3 | salas
# Processing record 35 of Set 3 | sakaiminato
# Processing record 36 of Set 3 | sioux lookout
# Processing record 37 of Set 3 | the valley
# Processing record 38 of Set 3 | anloga
# Processing record 39 of Set 3 | harper
# Processing record 40 of Set 3 | ambunti
# Processing record 41 of Set 3 | samalaeulu
# City samalaeulu not found. Skipping..............
# Processing record 42 of Set 3 | palmas de monte alto
# Processing record 43 of Set 3 | emerald
# Processing record 44 of Set 3 | kalmunai
# Processing record 45 of Set 3 | hvammstangi
# City hvammstangi not found. Skipping..............
# Processing record 46 of Set 3 | datong
# Processing record 47 of Set 3 | kashi
# Processing record 48 of Set 3 | okhansk
# Processing record 49 of Set 3 | tortoli
# Processing record 50 of Set 3 | oranjemund
# Processing record 51 of Set 3 | clyde river
# Processing record 52 of Set 3 | kulpahar
# Processing record 53 of Set 3 | sibolga
# Processing record 54 of Set 3 | buraydah
# Processing record 55 of Set 3 | am timan
# Processing record 56 of Set 3 | lingao
# Processing record 57 of Set 3 | ponta do sol
# Processing record 58 of Set 3 | oblivskaya
# Processing record 59 of Set 3 | cabo san lucas
# Processing record 60 of Set 3 | yulara
# Processing record 61 of Set 3 | harlingen
# Processing record 62 of Set 3 | nuevitas
# Processing record 63 of Set 3 | attawapiskat
# City attawapiskat not found. Skipping..............
# Processing record 64 of Set 3 | cayenne
# Processing record 65 of Set 3 | sabang
# Processing record 66 of Set 3 | meadow lake
# Processing record 67 of Set 3 | vao
# Processing record 68 of Set 3 | fort-shevchenko
# Processing record 69 of Set 3 | isangel
# Processing record 70 of Set 3 | les cayes
# Processing record 71 of Set 3 | itupiranga
# Processing record 72 of Set 3 | tromso
# Processing record 73 of Set 3 | solhan
# Processing record 74 of Set 3 | brandon
# Processing record 75 of Set 3 | palmer
# Processing record 76 of Set 3 | kenai
# Processing record 77 of Set 3 | touros
# Processing record 78 of Set 3 | marmande
# Processing record 79 of Set 3 | lagunas
# Processing record 80 of Set 3 | sevierville
# Processing record 81 of Set 3 | jojoima
# Processing record 82 of Set 3 | guryevsk
# Processing record 83 of Set 3 | yeppoon
# Processing record 84 of Set 3 | havoysund
# Processing record 85 of Set 3 | rutland
# Processing record 86 of Set 3 | shirokiy
# Processing record 87 of Set 3 | ust-nera
# Processing record 88 of Set 3 | east london
# Processing record 89 of Set 3 | denpasar
# Processing record 90 of Set 3 | cleveland
# Processing record 91 of Set 3 | aurdal
# Processing record 92 of Set 3 | saint-pierre
# Processing record 93 of Set 3 | zuya
# Processing record 94 of Set 3 | hailar
# Processing record 95 of Set 3 | broken hill
# Processing record 96 of Set 3 | egvekinot
# Processing record 97 of Set 3 | talnakh
# Processing record 98 of Set 3 | hamilton
# Processing record 99 of Set 3 | sabha
# Processing record 100 of Set 3 | los llanos de aridane
# Processing record 1 of Set 4 | omsukchan
# Processing record 2 of Set 4 | kirkwall
# Processing record 3 of Set 4 | airai
# Processing record 4 of Set 4 | nouakchott
# Processing record 5 of Set 4 | belaya gora
# Processing record 6 of Set 4 | atambua
# Processing record 7 of Set 4 | whitehorse
# Processing record 8 of Set 4 | whitianga
# Processing record 9 of Set 4 | tsihombe
# City tsihombe not found. Skipping..............
# Processing record 10 of Set 4 | sri aman
# Processing record 11 of Set 4 | trelleborg
# Processing record 12 of Set 4 | ustye
# Processing record 13 of Set 4 | maceio
# Processing record 14 of Set 4 | elblag
# Processing record 15 of Set 4 | vila velha
# Processing record 16 of Set 4 | ayr
# Processing record 17 of Set 4 | quba
# Processing record 18 of Set 4 | morondava
# Processing record 19 of Set 4 | palamos
# Processing record 20 of Set 4 | barbastro
# Processing record 21 of Set 4 | buala
# Processing record 22 of Set 4 | piacabucu
# Processing record 23 of Set 4 | sitka
# Processing record 24 of Set 4 | yenagoa
# Processing record 25 of Set 4 | torbay
# Processing record 26 of Set 4 | mahibadhoo
# Processing record 27 of Set 4 | dunedin
# Processing record 28 of Set 4 | northam
# Processing record 29 of Set 4 | pinawa
# Processing record 30 of Set 4 | saint-joseph
# Processing record 31 of Set 4 | naze
# Processing record 32 of Set 4 | talakan
# Processing record 33 of Set 4 | hasaki
# Processing record 34 of Set 4 | itarema
# Processing record 35 of Set 4 | naryan-mar
# Processing record 36 of Set 4 | puerto narino
# Processing record 37 of Set 4 | bouar
# Processing record 38 of Set 4 | najran
# Processing record 39 of Set 4 | chapais
# Processing record 40 of Set 4 | tahta
# Processing record 41 of Set 4 | taltal
# Processing record 42 of Set 4 | nago
# Processing record 43 of Set 4 | dingle
# Processing record 44 of Set 4 | chapayevka
# Processing record 45 of Set 4 | vardo
# Processing record 46 of Set 4 | namibe
# Processing record 47 of Set 4 | havre-saint-pierre
# Processing record 48 of Set 4 | ancud
# Processing record 49 of Set 4 | kendari
# Processing record 50 of Set 4 | terrace
# Processing record 51 of Set 4 | labe
# Processing record 52 of Set 4 | sisimiut
# Processing record 53 of Set 4 | ambikapur
# Processing record 54 of Set 4 | foix
# Processing record 55 of Set 4 | la ronge
# Processing record 56 of Set 4 | ngama
# Processing record 57 of Set 4 | beaverlodge
# Processing record 58 of Set 4 | pochutla
# Processing record 59 of Set 4 | cotonou
# Processing record 60 of Set 4 | beni mazar
# Processing record 61 of Set 4 | mayumba
# Processing record 62 of Set 4 | alofi
# Processing record 63 of Set 4 | namatanai
# Processing record 64 of Set 4 | beringovskiy
# Processing record 65 of Set 4 | yeniseysk
# Processing record 66 of Set 4 | ixtapa
# Processing record 67 of Set 4 | bend
# Processing record 68 of Set 4 | luderitz
# Processing record 69 of Set 4 | bagojo
# Processing record 70 of Set 4 | filingue
# Processing record 71 of Set 4 | brunico
# Processing record 72 of Set 4 | yamada
# Processing record 73 of Set 4 | kinkala
# Processing record 74 of Set 4 | grand river south east
# City grand river south east not found. Skipping..............
# Processing record 75 of Set 4 | henties bay
# Processing record 76 of Set 4 | qasigiannguit
# Processing record 77 of Set 4 | grafton
# Processing record 78 of Set 4 | ixtlan
# Processing record 79 of Set 4 | boa vista
# Processing record 80 of Set 4 | mackay
# Processing record 81 of Set 4 | canutama
# Processing record 82 of Set 4 | tilichiki
# Processing record 83 of Set 4 | chulym
# Processing record 84 of Set 4 | panarukan
# Processing record 85 of Set 4 | malwan
# City malwan not found. Skipping..............
# Processing record 86 of Set 4 | auki
# Processing record 87 of Set 4 | la palma
# Processing record 88 of Set 4 | arraias
# Processing record 89 of Set 4 | poltavka
# Processing record 90 of Set 4 | lossiemouth
# Processing record 91 of Set 4 | maloshuyka
# City maloshuyka not found. Skipping..............
# Processing record 92 of Set 4 | matamoros
# Processing record 93 of Set 4 | masyaf
# Processing record 94 of Set 4 | lebanon
# Processing record 95 of Set 4 | bom jesus
# Processing record 96 of Set 4 | innisfail
# Processing record 97 of Set 4 | merta
# Processing record 98 of Set 4 | sibundoy
# Processing record 99 of Set 4 | gelterkinden
# Processing record 100 of Set 4 | geresk
# City geresk not found. Skipping..............
# Processing record 1 of Set 5 | port hardy
# Processing record 2 of Set 5 | tetiz
# Processing record 3 of Set 5 | aranos
# Processing record 4 of Set 5 | chibombo
# Processing record 5 of Set 5 | dzilam gonzalez
# Processing record 6 of Set 5 | baisha
# Processing record 7 of Set 5 | abalak
# Processing record 8 of Set 5 | alekseyevsk
# Processing record 9 of Set 5 | half moon bay
# Processing record 10 of Set 5 | banjarmasin
# Processing record 11 of Set 5 | malartic
# Processing record 12 of Set 5 | los algarrobos
# Processing record 13 of Set 5 | lorengau
# Processing record 14 of Set 5 | polysayevo
# Processing record 15 of Set 5 | tumannyy
# City tumannyy not found. Skipping..............
# Processing record 16 of Set 5 | maniitsoq
# Processing record 17 of Set 5 | mugur-aksy
# Processing record 18 of Set 5 | petropavlovsk-kamchatskiy
# Processing record 19 of Set 5 | paramonga
# Processing record 20 of Set 5 | hohhot
# Processing record 21 of Set 5 | praia da vitoria
# Processing record 22 of Set 5 | nishihara
# Processing record 23 of Set 5 | lyuban
# Processing record 24 of Set 5 | joao pinheiro
# Processing record 25 of Set 5 | rocha
# Processing record 26 of Set 5 | brae
# Processing record 27 of Set 5 | palencia
# Processing record 28 of Set 5 | barranca
# Processing record 29 of Set 5 | north augusta
# Processing record 30 of Set 5 | port lincoln
# Processing record 31 of Set 5 | mahebourg
# Processing record 32 of Set 5 | ingham
# Processing record 33 of Set 5 | labuhan
# Processing record 34 of Set 5 | narkanda
# Processing record 35 of Set 5 | statesboro
# Processing record 36 of Set 5 | hella
# Processing record 37 of Set 5 | faya
# Processing record 38 of Set 5 | ojinaga
# Processing record 39 of Set 5 | denia
# Processing record 40 of Set 5 | kununurra
# Processing record 41 of Set 5 | honiara
# Processing record 42 of Set 5 | rognan
# Processing record 43 of Set 5 | katobu
# Processing record 44 of Set 5 | vilhena
# Processing record 45 of Set 5 | tuatapere
# Processing record 46 of Set 5 | tastur
# Processing record 47 of Set 5 | mukdahan
# Processing record 48 of Set 5 | syracuse
# Processing record 49 of Set 5 | antalaha
# Processing record 50 of Set 5 | bell ville
# Processing record 51 of Set 5 | maldonado
# Processing record 52 of Set 5 | umba
# Processing record 53 of Set 5 | nizhneyansk
# City nizhneyansk not found. Skipping..............
# Processing record 54 of Set 5 | vrangel
# Processing record 55 of Set 5 | waddan
# Processing record 56 of Set 5 | noumea
# Processing record 57 of Set 5 | marsa matruh
# Processing record 58 of Set 5 | makueni
# Processing record 59 of Set 5 | dhuburi
# Processing record 60 of Set 5 | vaitupu
# City vaitupu not found. Skipping..............
# Processing record 61 of Set 5 | gympie
# Processing record 62 of Set 5 | vetapalem
# Processing record 63 of Set 5 | bahia honda
# Processing record 64 of Set 5 | monrovia
# Processing record 65 of Set 5 | mykhaylivka
# Processing record 66 of Set 5 | bealanana
# Processing record 67 of Set 5 | nola
# Processing record 68 of Set 5 | saint-philippe
# Processing record 69 of Set 5 | ruatoria
# City ruatoria not found. Skipping..............
# Processing record 70 of Set 5 | falealupo
# City falealupo not found. Skipping..............
# Processing record 71 of Set 5 | port-gentil
# Processing record 72 of Set 5 | bambous virieux
# Processing record 73 of Set 5 | macomb
# Processing record 74 of Set 5 | ballina
# Processing record 75 of Set 5 | nantucket
# Processing record 76 of Set 5 | bathsheba
# Processing record 77 of Set 5 | banes
# Processing record 78 of Set 5 | jaen
# Processing record 79 of Set 5 | mayahi
# Processing record 80 of Set 5 | grand gaube
# Processing record 81 of Set 5 | bargal
# City bargal not found. Skipping..............
# Processing record 82 of Set 5 | brainerd
# Processing record 83 of Set 5 | asau
# Processing record 84 of Set 5 | diamantina
# Processing record 85 of Set 5 | sena madureira
# Processing record 86 of Set 5 | starosubkhangulovo
# Processing record 87 of Set 5 | sawakin
# Processing record 88 of Set 5 | samarai
# Processing record 89 of Set 5 | anshun
# Processing record 90 of Set 5 | xinan
# Processing record 91 of Set 5 | filiatra
# Processing record 92 of Set 5 | sola
# Processing record 93 of Set 5 | ulagan
# Processing record 94 of Set 5 | maghama
# City maghama not found. Skipping..............
# Processing record 95 of Set 5 | kaeo
# Processing record 96 of Set 5 | inirida
# Processing record 97 of Set 5 | batemans bay
# Processing record 98 of Set 5 | wahran
# City wahran not found. Skipping..............
# Processing record 99 of Set 5 | popondetta
# Processing record 100 of Set 5 | kruisfontein
# Processing record 1 of Set 6 | guerrero negro
# Processing record 2 of Set 6 | urdzhar
# City urdzhar not found. Skipping..............
# Processing record 3 of Set 6 | esperanza
# Processing record 4 of Set 6 | saint-paul
# Processing record 5 of Set 6 | derzhavinsk
# Processing record 6 of Set 6 | alice springs
# Processing record 7 of Set 6 | dalvik
# Processing record 8 of Set 6 | te anau
# Processing record 9 of Set 6 | ostashkov
# Processing record 10 of Set 6 | karamea
# City karamea not found. Skipping..............
# Processing record 11 of Set 6 | yako
# Processing record 12 of Set 6 | sur
# Processing record 13 of Set 6 | zhanatas
# City zhanatas not found. Skipping..............
# Processing record 14 of Set 6 | rangia
# Processing record 15 of Set 6 | svarstad
# Processing record 16 of Set 6 | durazno
# Processing record 17 of Set 6 | shihezi
# Processing record 18 of Set 6 | salalah
# Processing record 19 of Set 6 | hunchun
# Processing record 20 of Set 6 | dauriya
# Processing record 21 of Set 6 | quatre cocos
# Processing record 22 of Set 6 | mwanza
# Processing record 23 of Set 6 | binga
# Processing record 24 of Set 6 | gorno-chuyskiy
# City gorno-chuyskiy not found. Skipping..............
# Processing record 25 of Set 6 | manikganj
# Processing record 26 of Set 6 | makakilo city
# Processing record 27 of Set 6 | oktyabrskoye
# Processing record 28 of Set 6 | cahors
# Processing record 29 of Set 6 | itoman
# Processing record 30 of Set 6 | portland
# Processing record 31 of Set 6 | bubaque
# Processing record 32 of Set 6 | agropoli
# Processing record 33 of Set 6 | yarmouth
# Processing record 34 of Set 6 | lushunkou
# City lushunkou not found. Skipping..............
# Processing record 35 of Set 6 | oban
# Processing record 36 of Set 6 | hihifo
# City hihifo not found. Skipping..............
# Processing record 37 of Set 6 | tabou
# Processing record 38 of Set 6 | hervey bay
# Processing record 39 of Set 6 | leningradskiy
# Processing record 40 of Set 6 | ankara
# Processing record 41 of Set 6 | channagiri
# Processing record 42 of Set 6 | lucea
# Processing record 43 of Set 6 | santo antonio do leverger
# Processing record 44 of Set 6 | san cristobal
# Processing record 45 of Set 6 | qui nhon
# Processing record 46 of Set 6 | mitsamiouli
# Processing record 47 of Set 6 | goundam
# Processing record 48 of Set 6 | obo
# Processing record 49 of Set 6 | sorvag
# City sorvag not found. Skipping..............
# Processing record 50 of Set 6 | mizan teferi
# Processing record 51 of Set 6 | wajid
# Processing record 52 of Set 6 | yar-sale
# Processing record 53 of Set 6 | praxedis guerrero
# Processing record 54 of Set 6 | bontang
# Processing record 55 of Set 6 | okhotsk
# Processing record 56 of Set 6 | roald
# Processing record 57 of Set 6 | bilma
# Processing record 58 of Set 6 | kasulu
# Processing record 59 of Set 6 | amur
# Processing record 60 of Set 6 | launceston
# Processing record 61 of Set 6 | lagoa
# Processing record 62 of Set 6 | aden
# Processing record 63 of Set 6 | ferndale
# Processing record 64 of Set 6 | genhe
# Processing record 65 of Set 6 | santa lucia
# Processing record 66 of Set 6 | we
# City we not found. Skipping..............
# Processing record 67 of Set 6 | louisbourg
# City louisbourg not found. Skipping..............
# Processing record 68 of Set 6 | tairua
# Processing record 69 of Set 6 | nome
# Processing record 70 of Set 6 | papar
# Processing record 71 of Set 6 | christchurch
# Processing record 72 of Set 6 | rawson
# Processing record 73 of Set 6 | alyangula
# Processing record 74 of Set 6 | ust-maya
# Processing record 75 of Set 6 | killybegs
# Processing record 76 of Set 6 | peruwelz
# Processing record 77 of Set 6 | aurad
# Processing record 78 of Set 6 | narasapur
# Processing record 79 of Set 6 | togur
# Processing record 80 of Set 6 | tera
# Processing record 81 of Set 6 | bibiani
# Processing record 82 of Set 6 | darhan
# Processing record 83 of Set 6 | san jose
# Processing record 84 of Set 6 | phan thiet
# Processing record 85 of Set 6 | sohag
# Processing record 86 of Set 6 | dubti
# Processing record 87 of Set 6 | abancay
# Processing record 88 of Set 6 | jutai
# Processing record 89 of Set 6 | baykit
# Processing record 90 of Set 6 | martapura
# Processing record 91 of Set 6 | paris
# Processing record 92 of Set 6 | mbala
# Processing record 93 of Set 6 | westport
# Processing record 94 of Set 6 | caravelas
# Processing record 95 of Set 6 | kastamonu
# Processing record 96 of Set 6 | alugan
# Processing record 97 of Set 6 | chicama
# Processing record 98 of Set 6 | alotau
# City alotau not found. Skipping..............
# Processing record 99 of Set 6 | turka
# Processing record 100 of Set 6 | kahama
# Processing record 1 of Set 7 | avrille
# Processing record 2 of Set 7 | fukue
# Processing record 3 of Set 7 | moussoro
# Processing record 4 of Set 7 | manzhouli
# Processing record 5 of Set 7 | poya
# Processing record 6 of Set 7 | dolbeau
# City dolbeau not found. Skipping..............
# Processing record 7 of Set 7 | samana
# Processing record 8 of Set 7 | tigzirt
# Processing record 9 of Set 7 | carikar
# City carikar not found. Skipping..............
# Processing record 10 of Set 7 | antropovo
# Processing record 11 of Set 7 | yuancheng
# Processing record 12 of Set 7 | sirnak
# Processing record 13 of Set 7 | comodoro rivadavia
# Processing record 14 of Set 7 | altus
# Processing record 15 of Set 7 | chimbote
# Processing record 16 of Set 7 | ptichye
# Processing record 17 of Set 7 | saint-francois
# Processing record 18 of Set 7 | doha
# Processing record 19 of Set 7 | swan hill
# Processing record 20 of Set 7 | peniche
# Processing record 21 of Set 7 | lake charles
# Processing record 22 of Set 7 | muros
# Processing record 23 of Set 7 | syamzha
# Processing record 24 of Set 7 | ossora
# Processing record 25 of Set 7 | halalo
# City halalo not found. Skipping..............
# Processing record 26 of Set 7 | kinna
# Processing record 27 of Set 7 | daru
# Processing record 28 of Set 7 | bud
# Processing record 29 of Set 7 | rincon
# Processing record 30 of Set 7 | maralal
# Processing record 31 of Set 7 | ulladulla
# Processing record 32 of Set 7 | alto parana
# Processing record 33 of Set 7 | willmar
# Processing record 34 of Set 7 | ciudad bolivar
# Processing record 35 of Set 7 | liverpool
# Processing record 36 of Set 7 | zeya
# Processing record 37 of Set 7 | colesberg
# Processing record 38 of Set 7 | olafsvik
# Processing record 39 of Set 7 | gerash
# Processing record 40 of Set 7 | troitskoye
# Processing record 41 of Set 7 | ishinomaki
# Processing record 42 of Set 7 | berlevag
# Processing record 43 of Set 7 | churapcha
# Processing record 44 of Set 7 | kavaratti
# Processing record 45 of Set 7 | ugoofaaru
# Processing record 46 of Set 7 | magnitogorsk
# Processing record 47 of Set 7 | crab hill
# City crab hill not found. Skipping..............
# Processing record 48 of Set 7 | hambantota
# Processing record 49 of Set 7 | labuan
# Processing record 50 of Set 7 | eyl
# Processing record 51 of Set 7 | aksarka
# Processing record 52 of Set 7 | magole
# Processing record 53 of Set 7 | ucluelet
# Processing record 54 of Set 7 | laguna
# Processing record 55 of Set 7 | inuvik
# Processing record 56 of Set 7 | birao
# Processing record 57 of Set 7 | shingu
# Processing record 58 of Set 7 | hamada
# Processing record 59 of Set 7 | russellville
# Processing record 60 of Set 7 | lamar
# Processing record 61 of Set 7 | avera
# Processing record 62 of Set 7 | pitkyaranta
# Processing record 63 of Set 7 | chegdomyn
# Processing record 64 of Set 7 | edgewater
# Processing record 65 of Set 7 | mashhad
# Processing record 66 of Set 7 | yusva
# City yusva not found. Skipping..............
# Processing record 67 of Set 7 | high level
# Processing record 68 of Set 7 | nabire
# Processing record 69 of Set 7 | jiuquan
# Processing record 70 of Set 7 | pyaozerskiy
# Processing record 71 of Set 7 | yumen
# Processing record 72 of Set 7 | pinehurst
# Processing record 73 of Set 7 | aklavik
# Processing record 74 of Set 7 | tangshan
# Processing record 75 of Set 7 | ishigaki
# Processing record 76 of Set 7 | amapa
# Processing record 77 of Set 7 | beloha
# Processing record 78 of Set 7 | aguie
# Processing record 79 of Set 7 | yibin
# Processing record 80 of Set 7 | birin
# Processing record 81 of Set 7 | kirensk
# Processing record 82 of Set 7 | cherskiy
# Processing record 83 of Set 7 | shantipur
# Processing record 84 of Set 7 | sibu
# Processing record 85 of Set 7 | korla
# Processing record 86 of Set 7 | andevoranto
# City andevoranto not found. Skipping..............
# Processing record 87 of Set 7 | beni
# Processing record 88 of Set 7 | manama
# Processing record 89 of Set 7 | wairoa
# Processing record 90 of Set 7 | limot
# Processing record 91 of Set 7 | ankang
# Processing record 92 of Set 7 | batalha
# Processing record 93 of Set 7 | tapaua
# City tapaua not found. Skipping..............
# Processing record 94 of Set 7 | warrington
# Processing record 95 of Set 7 | kahului
# Processing record 96 of Set 7 | funtua
# Processing record 97 of Set 7 | seoul
# Processing record 98 of Set 7 | kitimat
# Processing record 99 of Set 7 | fez
# Processing record 100 of Set 7 | cervo
# Processing record 1 of Set 8 | raga
# Processing record 2 of Set 8 | toliary
# City toliary not found. Skipping..............
# Processing record 3 of Set 8 | playas
# Processing record 4 of Set 8 | altamira
# Processing record 5 of Set 8 | porbandar
# Processing record 6 of Set 8 | barwaha
# City barwaha not found. Skipping..............
# Processing record 7 of Set 8 | de-kastri
# Processing record 8 of Set 8 | belaya kholunitsa
# Processing record 9 of Set 8 | acapulco
# Processing record 10 of Set 8 | manukan
# Processing record 11 of Set 8 | chara
# Processing record 12 of Set 8 | salym
# Processing record 13 of Set 8 | boende
# Processing record 14 of Set 8 | jumla
# Processing record 15 of Set 8 | bandarbeyla
# Processing record 16 of Set 8 | skagastrond
# City skagastrond not found. Skipping..............
# Processing record 17 of Set 8 | samdari
# Processing record 18 of Set 8 | karaman
# Processing record 19 of Set 8 | bac lieu
# Processing record 20 of Set 8 | linhares
# Processing record 21 of Set 8 | cortez
# Processing record 22 of Set 8 | oktyabrskiy
# Processing record 23 of Set 8 | castlerea
# Processing record 24 of Set 8 | gasa
# Processing record 25 of Set 8 | tawnat
# City tawnat not found. Skipping..............
# Processing record 26 of Set 8 | ganzhou
# Processing record 27 of Set 8 | kuryk
# Processing record 28 of Set 8 | margate
# Processing record 29 of Set 8 | nowa deba
# Processing record 30 of Set 8 | priargunsk
# Processing record 31 of Set 8 | lekoni
# Processing record 32 of Set 8 | kulhudhuffushi
# Processing record 33 of Set 8 | acarau
# Processing record 34 of Set 8 | diego de almagro
# Processing record 35 of Set 8 | carndonagh
# Processing record 36 of Set 8 | sao miguel do araguaia
# Processing record 37 of Set 8 | pontal do parana
# Processing record 38 of Set 8 | elizabeth city
# Processing record 39 of Set 8 | merauke
# Processing record 40 of Set 8 | kamakwie
# Processing record 41 of Set 8 | fiche
# Processing record 42 of Set 8 | bulgan
# Processing record 43 of Set 8 | girona
# Processing record 44 of Set 8 | codrington
# Processing record 45 of Set 8 | grand-santi
# Processing record 46 of Set 8 | tual
# Processing record 47 of Set 8 | tavistock
# Processing record 48 of Set 8 | dwarka
# Processing record 49 of Set 8 | pandharpur
# Processing record 50 of Set 8 | koszalin
# Processing record 51 of Set 8 | forestville
# Processing record 52 of Set 8 | ligayan
# Processing record 53 of Set 8 | marawi
# Processing record 54 of Set 8 | vanavara
# Processing record 55 of Set 8 | mangrol
# Processing record 56 of Set 8 | ayagoz
# Processing record 57 of Set 8 | gigmoto
# Processing record 58 of Set 8 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert city data to a dataframe
city_data_df = pd.DataFrame(city_data)

# %%
# Re-order the columns
new_order = ['City', 'Country', 'Lat', 'Lng',
             'Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.15  -70.92     55.40        71          40
# 1    Butaritari      KI   3.07  172.79     82.08        77          34
# 2     Cape Town      ZA -33.93   18.42     57.99        76           0
# 3      Goderich      CA  43.75  -81.72     69.80        60         100
# 4          Hilo      US  19.73 -155.09     82.40        58          90
# 5    Lavrentiya      RU  65.58 -171.00     33.24        93         100
# 6      Thompson      CA  55.74  -97.86     14.00        92          90
# 7        Narwar      IN  25.65   77.90     61.34        42           0
# 8        Yishui      CN  35.78  118.63     57.02        46           0
# 9      Glendive      US  47.11 -104.71     30.20        80          90
#
#    Wind Speed Current Description
# 0        5.82    scattered clouds
# 1        7.58          light rain
# 2       10.29           clear sky
# 3       18.34     overcast clouds
# 4        6.93     overcast clouds
# 5        7.25     overcast clouds
# 6        4.70     overcast clouds
# 7        0.72           clear sky
# 8        6.60           clear sky
# 9       10.29     overcast clouds

# %%
# Exporting the dataframe to a csv file
city_data_df.to_csv('WeatherPy_Database.csv', index_label='City_ID')
