# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

from datetime import datetime
import requests

# Importing the API key for the weather
from configuration import  weather_api_key

# %%
# Generating 2000 random values for the longitude and the latitude
lat = np.random.uniform(-90,90,2000)
lng = np.random.uniform(-180,180,2000)

# Zipping the longitude and latitude arrays
lat_lng = zip(lat,lng)

# converting the zip to a list
coordinates = list(lat_lng)

# %%
# Creating an empty list for cities
cities = []

for coord in coordinates:
    city = citipy.nearest_city(coord[0],coord[1]).city_name

    # Check for duplicates
    if city not in cities:
        cities.append(city)

# %%
# Parameters for the request
params = {
    'q': cities[-4],
    'appid': weather_api_key
}
# Build the url
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial'

requests.get(url=url,params=params).json()
# Out:
# {'coord': {'lon': -158.09, 'lat': 21.35},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 76.24,
#   'feels_like': 82.35,
#   'temp_min': 71.6,
#   'temp_max': 80.01,
#   'pressure': 1017,
#   'humidity': 83},
#  'visibility': 10000,
#  'wind': {'speed': 3.36, 'deg': 60},
#  'clouds': {'all': 1},
#  'dt': 1604828015,
#  'sys': {'type': 1,
#   'id': 7868,
#   'country': 'US',
#   'sunrise': 1604767142,
#   'sunset': 1604807592},
#  'timezone': -36000,
#  'id': 5850554,
#  'name': 'Makakilo City',
#  'cod': 200}

# %%
# Build the url
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial'

# Parameters for the request
params = {
    'q': '',
    'appid': weather_api_key
}

# Create an empty list to store the information that will be captured
city_data = []

# Print the beginning of the logging process
print('Beginning the data retrieval')
print('****************************')

record_count = 1
set_count = 1

for index, city in enumerate(cities):
    params['q'] = city

    if index % 100 == 0 and index >= 100:
        set_count += 1
        record_count = 1

    # Logging the URL, record number, set number and city
    print(f'Processing record {record_count} of Set {set_count} | {city}')
    record_count += 1

    try:
        city_weather = requests.get(url=base_url,params=params).json()
        # city_data.append(city_weather['coord']['lat'])
        city_data.append({
            'City': city.title(),
            'Lat': city_weather['coord']['lat'],
            'Lng': city_weather['coord']['lon'],
            'Humidity': city_weather['main']['humidity'],
            'Cloudiness': city_weather['clouds']['all'],
            'Max Temp': city_weather['main']['temp_max'],
            'Wind Speed': city_weather['wind']['speed'],
            'Country': city_weather['sys']['country'],
            'Current Description': city_weather['weather'][0]['description']
        })
    except:
        print(f'City {city} not found. Skipping..............')

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning the data retrieval
# ****************************
# Processing record 1 of Set 1 | albany
# Processing record 2 of Set 1 | mao
# Processing record 3 of Set 1 | illoqqortoormiut
# City illoqqortoormiut not found. Skipping..............
# Processing record 4 of Set 1 | butaritari
# Processing record 5 of Set 1 | nanortalik
# Processing record 6 of Set 1 | cherskiy
# Processing record 7 of Set 1 | qaanaaq
# Processing record 8 of Set 1 | busselton
# Processing record 9 of Set 1 | cidreira
# Processing record 10 of Set 1 | hami
# Processing record 11 of Set 1 | vaini
# Processing record 12 of Set 1 | atuona
# Processing record 13 of Set 1 | cabo san lucas
# Processing record 14 of Set 1 | rikitea
# Processing record 15 of Set 1 | taolanaro
# City taolanaro not found. Skipping..............
# Processing record 16 of Set 1 | geraldton
# Processing record 17 of Set 1 | galesburg
# Processing record 18 of Set 1 | tambacounda
# Processing record 19 of Set 1 | klaksvik
# Processing record 20 of Set 1 | barrow
# Processing record 21 of Set 1 | kapaa
# Processing record 22 of Set 1 | buala
# Processing record 23 of Set 1 | belmonte
# Processing record 24 of Set 1 | nelson bay
# Processing record 25 of Set 1 | samana
# Processing record 26 of Set 1 | tuktoyaktuk
# Processing record 27 of Set 1 | tocopilla
# Processing record 28 of Set 1 | puerto ayora
# Processing record 29 of Set 1 | mahebourg
# Processing record 30 of Set 1 | teknaf
# Processing record 31 of Set 1 | srednekolymsk
# Processing record 32 of Set 1 | ardistan
# City ardistan not found. Skipping..............
# Processing record 33 of Set 1 | upernavik
# Processing record 34 of Set 1 | severo-kurilsk
# Processing record 35 of Set 1 | kodiak
# Processing record 36 of Set 1 | tlapehuala
# Processing record 37 of Set 1 | dracena
# Processing record 38 of Set 1 | ciudad bolivar
# Processing record 39 of Set 1 | anadyr
# Processing record 40 of Set 1 | punta arenas
# Processing record 41 of Set 1 | ushuaia
# Processing record 42 of Set 1 | faanui
# Processing record 43 of Set 1 | bonthe
# Processing record 44 of Set 1 | carnarvon
# Processing record 45 of Set 1 | saint-philippe
# Processing record 46 of Set 1 | bluff
# Processing record 47 of Set 1 | port elizabeth
# Processing record 48 of Set 1 | presidente franco
# Processing record 49 of Set 1 | georgetown
# Processing record 50 of Set 1 | ferrol
# Processing record 51 of Set 1 | kangaatsiaq
# Processing record 52 of Set 1 | hilo
# Processing record 53 of Set 1 | san cristobal
# Processing record 54 of Set 1 | guilin
# Processing record 55 of Set 1 | moose factory
# Processing record 56 of Set 1 | hobart
# Processing record 57 of Set 1 | haines junction
# Processing record 58 of Set 1 | avera
# Processing record 59 of Set 1 | nizhneyansk
# City nizhneyansk not found. Skipping..............
# Processing record 60 of Set 1 | port alfred
# Processing record 61 of Set 1 | mar del plata
# Processing record 62 of Set 1 | tuatapere
# Processing record 63 of Set 1 | namuac
# Processing record 64 of Set 1 | arraial do cabo
# Processing record 65 of Set 1 | hanstholm
# Processing record 66 of Set 1 | mantua
# Processing record 67 of Set 1 | tambul
# City tambul not found. Skipping..............
# Processing record 68 of Set 1 | grindavik
# Processing record 69 of Set 1 | mys shmidta
# City mys shmidta not found. Skipping..............
# Processing record 70 of Set 1 | pevek
# Processing record 71 of Set 1 | hithadhoo
# Processing record 72 of Set 1 | nioro
# Processing record 73 of Set 1 | alferrarede
# Processing record 74 of Set 1 | shizuishan
# Processing record 75 of Set 1 | santa rosa
# Processing record 76 of Set 1 | seddon
# Processing record 77 of Set 1 | amderma
# City amderma not found. Skipping..............
# Processing record 78 of Set 1 | mount gambier
# Processing record 79 of Set 1 | bambous virieux
# Processing record 80 of Set 1 | naryan-mar
# Processing record 81 of Set 1 | bethanien
# Processing record 82 of Set 1 | constitucion
# Processing record 83 of Set 1 | lakes entrance
# Processing record 84 of Set 1 | ketchikan
# Processing record 85 of Set 1 | ballina
# Processing record 86 of Set 1 | umzimvubu
# City umzimvubu not found. Skipping..............
# Processing record 87 of Set 1 | new norfolk
# Processing record 88 of Set 1 | jamestown
# Processing record 89 of Set 1 | ambovombe
# Processing record 90 of Set 1 | dubbo
# Processing record 91 of Set 1 | takaka
# Processing record 92 of Set 1 | thompson
# Processing record 93 of Set 1 | riyadh
# Processing record 94 of Set 1 | luderitz
# Processing record 95 of Set 1 | kahului
# Processing record 96 of Set 1 | cape town
# Processing record 97 of Set 1 | mataura
# Processing record 98 of Set 1 | flinders
# Processing record 99 of Set 1 | avarua
# Processing record 100 of Set 1 | goderich
# Processing record 1 of Set 2 | kalmunai
# Processing record 2 of Set 2 | samusu
# City samusu not found. Skipping..............
# Processing record 3 of Set 2 | golden gate
# Processing record 4 of Set 2 | pareora
# Processing record 5 of Set 2 | mogadouro
# Processing record 6 of Set 2 | angoche
# Processing record 7 of Set 2 | leningradskiy
# Processing record 8 of Set 2 | nantucket
# Processing record 9 of Set 2 | lebu
# Processing record 10 of Set 2 | port blair
# Processing record 11 of Set 2 | sentyabrskiy
# City sentyabrskiy not found. Skipping..............
# Processing record 12 of Set 2 | ruatoria
# City ruatoria not found. Skipping..............
# Processing record 13 of Set 2 | odweyne
# Processing record 14 of Set 2 | victoria
# Processing record 15 of Set 2 | ahipara
# Processing record 16 of Set 2 | dolbeau
# City dolbeau not found. Skipping..............
# Processing record 17 of Set 2 | vanavara
# Processing record 18 of Set 2 | hermanus
# Processing record 19 of Set 2 | fortuna
# Processing record 20 of Set 2 | biltine
# Processing record 21 of Set 2 | khatanga
# Processing record 22 of Set 2 | torbay
# Processing record 23 of Set 2 | acapulco
# Processing record 24 of Set 2 | sao felix do xingu
# Processing record 25 of Set 2 | praia da vitoria
# Processing record 26 of Set 2 | sisimiut
# Processing record 27 of Set 2 | broome
# Processing record 28 of Set 2 | ilulissat
# Processing record 29 of Set 2 | olinda
# Processing record 30 of Set 2 | tawkar
# City tawkar not found. Skipping..............
# Processing record 31 of Set 2 | vestmannaeyjar
# Processing record 32 of Set 2 | deputatskiy
# Processing record 33 of Set 2 | tamiahua
# Processing record 34 of Set 2 | satitoa
# City satitoa not found. Skipping..............
# Processing record 35 of Set 2 | portland
# Processing record 36 of Set 2 | nikolskoye
# Processing record 37 of Set 2 | stabat
# Processing record 38 of Set 2 | coihaique
# Processing record 39 of Set 2 | mehamn
# Processing record 40 of Set 2 | meiganga
# Processing record 41 of Set 2 | dunedin
# Processing record 42 of Set 2 | capitan bado
# Processing record 43 of Set 2 | santa marta
# Processing record 44 of Set 2 | cayenne
# Processing record 45 of Set 2 | manoel urbano
# Processing record 46 of Set 2 | kabanjahe
# Processing record 47 of Set 2 | beringovskiy
# Processing record 48 of Set 2 | mapiripan
# Processing record 49 of Set 2 | berlevag
# Processing record 50 of Set 2 | bay-khaak
# Processing record 51 of Set 2 | gonda
# Processing record 52 of Set 2 | brigantine
# Processing record 53 of Set 2 | asfi
# Processing record 54 of Set 2 | chuy
# Processing record 55 of Set 2 | lufilufi
# Processing record 56 of Set 2 | attawapiskat
# City attawapiskat not found. Skipping..............
# Processing record 57 of Set 2 | tiksi
# Processing record 58 of Set 2 | kieta
# Processing record 59 of Set 2 | merritt island
# Processing record 60 of Set 2 | coruripe
# Processing record 61 of Set 2 | kruisfontein
# Processing record 62 of Set 2 | norman wells
# Processing record 63 of Set 2 | kribi
# Processing record 64 of Set 2 | mount isa
# Processing record 65 of Set 2 | ereymentau
# Processing record 66 of Set 2 | kloulklubed
# Processing record 67 of Set 2 | aklavik
# Processing record 68 of Set 2 | bedesa
# Processing record 69 of Set 2 | tsihombe
# City tsihombe not found. Skipping..............
# Processing record 70 of Set 2 | prince rupert
# Processing record 71 of Set 2 | castro
# Processing record 72 of Set 2 | tete
# Processing record 73 of Set 2 | yuzawa
# Processing record 74 of Set 2 | laguna
# Processing record 75 of Set 2 | alekseyevsk
# Processing record 76 of Set 2 | kaitangata
# Processing record 77 of Set 2 | njombe
# Processing record 78 of Set 2 | port lincoln
# Processing record 79 of Set 2 | bredasdorp
# Processing record 80 of Set 2 | naze
# Processing record 81 of Set 2 | bethel
# Processing record 82 of Set 2 | chowchilla
# Processing record 83 of Set 2 | umm kaddadah
# Processing record 84 of Set 2 | east london
# Processing record 85 of Set 2 | ostrovnoy
# Processing record 86 of Set 2 | bar-le-duc
# Processing record 87 of Set 2 | grand gaube
# Processing record 88 of Set 2 | ancud
# Processing record 89 of Set 2 | belushya guba
# City belushya guba not found. Skipping..............
# Processing record 90 of Set 2 | sidi bu zayd
# City sidi bu zayd not found. Skipping..............
# Processing record 91 of Set 2 | ambon
# Processing record 92 of Set 2 | gat
# Processing record 93 of Set 2 | barentsburg
# City barentsburg not found. Skipping..............
# Processing record 94 of Set 2 | san carlos de bariloche
# Processing record 95 of Set 2 | rio gallegos
# Processing record 96 of Set 2 | rawannawi
# City rawannawi not found. Skipping..............
# Processing record 97 of Set 2 | karratha
# Processing record 98 of Set 2 | charagua
# Processing record 99 of Set 2 | saint george
# Processing record 100 of Set 2 | imbituba
# Processing record 1 of Set 3 | asau
# Processing record 2 of Set 3 | baglung
# Processing record 3 of Set 3 | mayo
# Processing record 4 of Set 3 | presidencia roque saenz pena
# Processing record 5 of Set 3 | rawson
# Processing record 6 of Set 3 | hobyo
# Processing record 7 of Set 3 | zhigansk
# Processing record 8 of Set 3 | warqla
# City warqla not found. Skipping..............
# Processing record 9 of Set 3 | simbach
# Processing record 10 of Set 3 | airai
# Processing record 11 of Set 3 | cururupu
# Processing record 12 of Set 3 | vardo
# Processing record 13 of Set 3 | baruun-urt
# Processing record 14 of Set 3 | waipawa
# Processing record 15 of Set 3 | yangmei
# Processing record 16 of Set 3 | varkkallai
# Processing record 17 of Set 3 | ust-kamchatsk
# City ust-kamchatsk not found. Skipping..............
# Processing record 18 of Set 3 | ponta delgada
# Processing record 19 of Set 3 | souillac
# Processing record 20 of Set 3 | pecos
# Processing record 21 of Set 3 | zhangye
# Processing record 22 of Set 3 | taoudenni
# Processing record 23 of Set 3 | bajil
# Processing record 24 of Set 3 | ixtapa
# Processing record 25 of Set 3 | vila velha
# Processing record 26 of Set 3 | evensk
# Processing record 27 of Set 3 | bandar-e lengeh
# Processing record 28 of Set 3 | matamoros
# Processing record 29 of Set 3 | porirua
# Processing record 30 of Set 3 | panzhihua
# Processing record 31 of Set 3 | faya
# Processing record 32 of Set 3 | dikson
# Processing record 33 of Set 3 | nakamura
# Processing record 34 of Set 3 | chokurdakh
# Processing record 35 of Set 3 | tokzar
# City tokzar not found. Skipping..............
# Processing record 36 of Set 3 | bilibino
# Processing record 37 of Set 3 | brentwood
# Processing record 38 of Set 3 | nago
# Processing record 39 of Set 3 | aitape
# Processing record 40 of Set 3 | manitouwadge
# Processing record 41 of Set 3 | gidole
# Processing record 42 of Set 3 | provideniya
# Processing record 43 of Set 3 | lerik
# Processing record 44 of Set 3 | port hedland
# Processing record 45 of Set 3 | victoria point
# Processing record 46 of Set 3 | amapa
# Processing record 47 of Set 3 | cazaje
# City cazaje not found. Skipping..............
# Processing record 48 of Set 3 | tasiilaq
# Processing record 49 of Set 3 | manono
# Processing record 50 of Set 3 | buraydah
# Processing record 51 of Set 3 | katsuura
# Processing record 52 of Set 3 | sakakah
# Processing record 53 of Set 3 | caravelas
# Processing record 54 of Set 3 | abu zabad
# Processing record 55 of Set 3 | tessalit
# Processing record 56 of Set 3 | nouakchott
# Processing record 57 of Set 3 | bucerias
# Processing record 58 of Set 3 | muyezerskiy
# Processing record 59 of Set 3 | gobabis
# Processing record 60 of Set 3 | tanout
# Processing record 61 of Set 3 | bonavista
# Processing record 62 of Set 3 | saldanha
# Processing record 63 of Set 3 | shimoda
# Processing record 64 of Set 3 | half moon bay
# Processing record 65 of Set 3 | sao paulo de olivenca
# Processing record 66 of Set 3 | thunder bay
# Processing record 67 of Set 3 | saint-pierre
# Processing record 68 of Set 3 | moree
# Processing record 69 of Set 3 | touros
# Processing record 70 of Set 3 | una
# Processing record 71 of Set 3 | hualmay
# Processing record 72 of Set 3 | gravdal
# Processing record 73 of Set 3 | ampanihy
# Processing record 74 of Set 3 | nieves
# Processing record 75 of Set 3 | prainha
# Processing record 76 of Set 3 | klyuchi
# Processing record 77 of Set 3 | marsabit
# Processing record 78 of Set 3 | maragogi
# Processing record 79 of Set 3 | isangel
# Processing record 80 of Set 3 | vanimo
# Processing record 81 of Set 3 | minudasht
# Processing record 82 of Set 3 | san quintin
# Processing record 83 of Set 3 | aksarka
# Processing record 84 of Set 3 | koumac
# Processing record 85 of Set 3 | kutum
# Processing record 86 of Set 3 | tateyama
# Processing record 87 of Set 3 | den helder
# Processing record 88 of Set 3 | roma
# Processing record 89 of Set 3 | ribeira grande
# Processing record 90 of Set 3 | clyde river
# Processing record 91 of Set 3 | kralendijk
# Processing record 92 of Set 3 | udachnyy
# Processing record 93 of Set 3 | conceicao da barra
# Processing record 94 of Set 3 | aquiraz
# Processing record 95 of Set 3 | vostok
# Processing record 96 of Set 3 | honningsvag
# Processing record 97 of Set 3 | alyangula
# Processing record 98 of Set 3 | namibe
# Processing record 99 of Set 3 | havoysund
# Processing record 100 of Set 3 | oriximina
# Processing record 1 of Set 4 | domoni
# Processing record 2 of Set 4 | lorengau
# Processing record 3 of Set 4 | savonlinna
# Processing record 4 of Set 4 | longyearbyen
# Processing record 5 of Set 4 | tukrah
# Processing record 6 of Set 4 | yago
# Processing record 7 of Set 4 | nara
# Processing record 8 of Set 4 | tolaga bay
# Processing record 9 of Set 4 | narsaq
# Processing record 10 of Set 4 | qui nhon
# Processing record 11 of Set 4 | kambove
# Processing record 12 of Set 4 | vao
# Processing record 13 of Set 4 | pakhtakoron
# Processing record 14 of Set 4 | letlhakane
# Processing record 15 of Set 4 | jatiroto
# Processing record 16 of Set 4 | hofn
# Processing record 17 of Set 4 | bandarbeyla
# Processing record 18 of Set 4 | cesme
# Processing record 19 of Set 4 | lavrentiya
# Processing record 20 of Set 4 | chiang klang
# Processing record 21 of Set 4 | tezu
# Processing record 22 of Set 4 | yulara
# Processing record 23 of Set 4 | margate
# Processing record 24 of Set 4 | los llanos de aridane
# Processing record 25 of Set 4 | bathsheba
# Processing record 26 of Set 4 | lompoc
# Processing record 27 of Set 4 | zyryanka
# Processing record 28 of Set 4 | grand river south east
# City grand river south east not found. Skipping..............
# Processing record 29 of Set 4 | ola
# Processing record 30 of Set 4 | jasper
# Processing record 31 of Set 4 | hibbing
# Processing record 32 of Set 4 | mandali
# Processing record 33 of Set 4 | mahibadhoo
# Processing record 34 of Set 4 | wahpeton
# Processing record 35 of Set 4 | esperance
# Processing record 36 of Set 4 | gornopravdinsk
# Processing record 37 of Set 4 | swan river
# Processing record 38 of Set 4 | adelaide
# Processing record 39 of Set 4 | finschhafen
# Processing record 40 of Set 4 | vaitupu
# City vaitupu not found. Skipping..............
# Processing record 41 of Set 4 | puerto del rosario
# Processing record 42 of Set 4 | dezful
# Processing record 43 of Set 4 | ningan
# City ningan not found. Skipping..............
# Processing record 44 of Set 4 | port macquarie
# Processing record 45 of Set 4 | tabiauea
# City tabiauea not found. Skipping..............
# Processing record 46 of Set 4 | sinnamary
# Processing record 47 of Set 4 | abadan
# Processing record 48 of Set 4 | fort saint john
# City fort saint john not found. Skipping..............
# Processing record 49 of Set 4 | antofagasta
# Processing record 50 of Set 4 | bressanone
# Processing record 51 of Set 4 | ngunguru
# Processing record 52 of Set 4 | sur
# Processing record 53 of Set 4 | devonport
# Processing record 54 of Set 4 | saskylakh
# Processing record 55 of Set 4 | rudnya
# Processing record 56 of Set 4 | aripuana
# Processing record 57 of Set 4 | meulaboh
# Processing record 58 of Set 4 | havelock
# Processing record 59 of Set 4 | gizo
# Processing record 60 of Set 4 | statesboro
# Processing record 61 of Set 4 | chamalieres
# Processing record 62 of Set 4 | cabra
# Processing record 63 of Set 4 | palabuhanratu
# City palabuhanratu not found. Skipping..............
# Processing record 64 of Set 4 | pathalgaon
# Processing record 65 of Set 4 | krasnokamensk
# Processing record 66 of Set 4 | morondava
# Processing record 67 of Set 4 | le vauclin
# Processing record 68 of Set 4 | husavik
# Processing record 69 of Set 4 | nabire
# Processing record 70 of Set 4 | oranjemund
# Processing record 71 of Set 4 | jijiga
# Processing record 72 of Set 4 | rawah
# Processing record 73 of Set 4 | hunza
# City hunza not found. Skipping..............
# Processing record 74 of Set 4 | kericho
# Processing record 75 of Set 4 | bosaso
# Processing record 76 of Set 4 | umm durman
# City umm durman not found. Skipping..............
# Processing record 77 of Set 4 | igarka
# Processing record 78 of Set 4 | goundam
# Processing record 79 of Set 4 | khuzhir
# Processing record 80 of Set 4 | saleaula
# City saleaula not found. Skipping..............
# Processing record 81 of Set 4 | pemangkat
# Processing record 82 of Set 4 | azar shahr
# City azar shahr not found. Skipping..............
# Processing record 83 of Set 4 | yellowknife
# Processing record 84 of Set 4 | igrim
# Processing record 85 of Set 4 | shanghai
# Processing record 86 of Set 4 | gainesville
# Processing record 87 of Set 4 | hornepayne
# Processing record 88 of Set 4 | damietta
# Processing record 89 of Set 4 | charyshskoye
# Processing record 90 of Set 4 | khani
# Processing record 91 of Set 4 | san patricio
# Processing record 92 of Set 4 | tiznit
# Processing record 93 of Set 4 | cangucu
# Processing record 94 of Set 4 | tornio
# Processing record 95 of Set 4 | cabedelo
# Processing record 96 of Set 4 | teguldet
# Processing record 97 of Set 4 | ponerihouen
# Processing record 98 of Set 4 | pingliang
# Processing record 99 of Set 4 | la rioja
# Processing record 100 of Set 4 | cumbitara
# Processing record 1 of Set 5 | adrar
# Processing record 2 of Set 5 | ternate
# Processing record 3 of Set 5 | russell
# Processing record 4 of Set 5 | pribelskiy
# City pribelskiy not found. Skipping..............
# Processing record 5 of Set 5 | velasco ibarra
# Processing record 6 of Set 5 | dom pedrito
# Processing record 7 of Set 5 | northampton
# Processing record 8 of Set 5 | cerritos
# Processing record 9 of Set 5 | lebedinyy
# Processing record 10 of Set 5 | nhulunbuy
# Processing record 11 of Set 5 | aranos
# Processing record 12 of Set 5 | suntar
# Processing record 13 of Set 5 | beckley
# Processing record 14 of Set 5 | kudahuvadhoo
# Processing record 15 of Set 5 | nosy varika
# Processing record 16 of Set 5 | olafsvik
# Processing record 17 of Set 5 | fortaleza
# Processing record 18 of Set 5 | kardamaina
# Processing record 19 of Set 5 | stettler
# Processing record 20 of Set 5 | tumannyy
# City tumannyy not found. Skipping..............
# Processing record 21 of Set 5 | winnemucca
# Processing record 22 of Set 5 | dingle
# Processing record 23 of Set 5 | te anau
# Processing record 24 of Set 5 | tongliao
# Processing record 25 of Set 5 | rio de jesus
# Processing record 26 of Set 5 | rungata
# City rungata not found. Skipping..............
# Processing record 27 of Set 5 | balabac
# Processing record 28 of Set 5 | samarai
# Processing record 29 of Set 5 | khorinsk
# Processing record 30 of Set 5 | magistralnyy
# Processing record 31 of Set 5 | hvammstangi
# City hvammstangi not found. Skipping..............
# Processing record 32 of Set 5 | gold coast
# Processing record 33 of Set 5 | puebloviejo
# Processing record 34 of Set 5 | san pedro
# Processing record 35 of Set 5 | guerrero negro
# Processing record 36 of Set 5 | bull savanna
# Processing record 37 of Set 5 | lagoa
# Processing record 38 of Set 5 | sao filipe
# Processing record 39 of Set 5 | paamiut
# Processing record 40 of Set 5 | ngukurr
# City ngukurr not found. Skipping..............
# Processing record 41 of Set 5 | antsohihy
# Processing record 42 of Set 5 | betioky
# Processing record 43 of Set 5 | saint-francois
# Processing record 44 of Set 5 | carlet
# Processing record 45 of Set 5 | awbari
# Processing record 46 of Set 5 | erenhot
# Processing record 47 of Set 5 | kaitong
# Processing record 48 of Set 5 | costinesti
# Processing record 49 of Set 5 | mitsamiouli
# Processing record 50 of Set 5 | severn
# Processing record 51 of Set 5 | perigueux
# Processing record 52 of Set 5 | toamasina
# Processing record 53 of Set 5 | kavieng
# Processing record 54 of Set 5 | salalah
# Processing record 55 of Set 5 | banmo
# City banmo not found. Skipping..............
# Processing record 56 of Set 5 | ca mau
# Processing record 57 of Set 5 | caucaia
# Processing record 58 of Set 5 | totness
# Processing record 59 of Set 5 | goundi
# Processing record 60 of Set 5 | talnakh
# Processing record 61 of Set 5 | eidfjord
# Processing record 62 of Set 5 | kyra
# Processing record 63 of Set 5 | hanna
# Processing record 64 of Set 5 | bardiyah
# Processing record 65 of Set 5 | kavaratti
# Processing record 66 of Set 5 | tabialan
# City tabialan not found. Skipping..............
# Processing record 67 of Set 5 | tunduru
# City tunduru not found. Skipping..............
# Processing record 68 of Set 5 | akureyri
# Processing record 69 of Set 5 | nome
# Processing record 70 of Set 5 | puerto carreno
# Processing record 71 of Set 5 | wanning
# Processing record 72 of Set 5 | jiazi
# Processing record 73 of Set 5 | taksimo
# Processing record 74 of Set 5 | hambantota
# Processing record 75 of Set 5 | stephenville crossing
# Processing record 76 of Set 5 | albury
# Processing record 77 of Set 5 | obo
# Processing record 78 of Set 5 | north bend
# Processing record 79 of Set 5 | fartura
# Processing record 80 of Set 5 | baillif
# Processing record 81 of Set 5 | carutapera
# Processing record 82 of Set 5 | sistranda
# Processing record 83 of Set 5 | emba
# Processing record 84 of Set 5 | port shepstone
# Processing record 85 of Set 5 | saint-denis
# Processing record 86 of Set 5 | atar
# Processing record 87 of Set 5 | payakumbuh
# Processing record 88 of Set 5 | port moresby
# Processing record 89 of Set 5 | bogande
# Processing record 90 of Set 5 | nagua
# Processing record 91 of Set 5 | batemans bay
# Processing record 92 of Set 5 | iquique
# Processing record 93 of Set 5 | luena
# Processing record 94 of Set 5 | maroua
# Processing record 95 of Set 5 | san
# Processing record 96 of Set 5 | acarau
# Processing record 97 of Set 5 | westerland
# Processing record 98 of Set 5 | murgab
# Processing record 99 of Set 5 | cockburn town
# Processing record 100 of Set 5 | alta floresta
# Processing record 1 of Set 6 | lethem
# Processing record 2 of Set 6 | oistins
# Processing record 3 of Set 6 | shingu
# Processing record 4 of Set 6 | meadville
# Processing record 5 of Set 6 | bengkulu
# Processing record 6 of Set 6 | sao joao da barra
# Processing record 7 of Set 6 | menongue
# Processing record 8 of Set 6 | veraval
# Processing record 9 of Set 6 | byron bay
# Processing record 10 of Set 6 | jacksonville
# Processing record 11 of Set 6 | yerbogachen
# Processing record 12 of Set 6 | sao raimundo das mangabeiras
# Processing record 13 of Set 6 | rundu
# Processing record 14 of Set 6 | segou
# Processing record 15 of Set 6 | berezovka
# Processing record 16 of Set 6 | tabuk
# Processing record 17 of Set 6 | sitka
# Processing record 18 of Set 6 | kirakira
# Processing record 19 of Set 6 | rio grande
# Processing record 20 of Set 6 | arman
# Processing record 21 of Set 6 | odessa
# Processing record 22 of Set 6 | kafanchan
# Processing record 23 of Set 6 | calabozo
# Processing record 24 of Set 6 | mandiana
# Processing record 25 of Set 6 | paragominas
# Processing record 26 of Set 6 | pahrump
# Processing record 27 of Set 6 | gao
# Processing record 28 of Set 6 | karauzyak
# City karauzyak not found. Skipping..............
# Processing record 29 of Set 6 | motul
# Processing record 30 of Set 6 | toliary
# City toliary not found. Skipping..............
# Processing record 31 of Set 6 | ingham
# Processing record 32 of Set 6 | bakchar
# Processing record 33 of Set 6 | bud
# Processing record 34 of Set 6 | toora-khem
# Processing record 35 of Set 6 | palmer
# Processing record 36 of Set 6 | sabya
# Processing record 37 of Set 6 | biak
# Processing record 38 of Set 6 | sumbe
# Processing record 39 of Set 6 | kjollefjord
# Processing record 40 of Set 6 | dondo
# Processing record 41 of Set 6 | seydi
# Processing record 42 of Set 6 | cardston
# Processing record 43 of Set 6 | kimbe
# Processing record 44 of Set 6 | magadan
# Processing record 45 of Set 6 | haldensleben
# Processing record 46 of Set 6 | jatara
# Processing record 47 of Set 6 | marcona
# City marcona not found. Skipping..............
# Processing record 48 of Set 6 | sabang
# Processing record 49 of Set 6 | zatoka
# Processing record 50 of Set 6 | formoso do araguaia
# City formoso do araguaia not found. Skipping..............
# Processing record 51 of Set 6 | vila franca do campo
# Processing record 52 of Set 6 | yagodnoye
# Processing record 53 of Set 6 | lolua
# City lolua not found. Skipping..............
# Processing record 54 of Set 6 | bargal
# City bargal not found. Skipping..............
# Processing record 55 of Set 6 | egvekinot
# Processing record 56 of Set 6 | iqaluit
# Processing record 57 of Set 6 | macaboboni
# City macaboboni not found. Skipping..............
# Processing record 58 of Set 6 | terrace
# Processing record 59 of Set 6 | arlit
# Processing record 60 of Set 6 | severo-yeniseyskiy
# Processing record 61 of Set 6 | sept-iles
# Processing record 62 of Set 6 | rockland
# Processing record 63 of Set 6 | rolla
# Processing record 64 of Set 6 | burica
# City burica not found. Skipping..............
# Processing record 65 of Set 6 | champerico
# Processing record 66 of Set 6 | terrak
# Processing record 67 of Set 6 | churapcha
# Processing record 68 of Set 6 | whitianga
# Processing record 69 of Set 6 | bandar-e torkaman
# City bandar-e torkaman not found. Skipping..............
# Processing record 70 of Set 6 | altar
# Processing record 71 of Set 6 | viligili
# City viligili not found. Skipping..............
# Processing record 72 of Set 6 | walvis bay
# Processing record 73 of Set 6 | usevya
# Processing record 74 of Set 6 | salisbury
# Processing record 75 of Set 6 | buqayq
# City buqayq not found. Skipping..............
# Processing record 76 of Set 6 | hermiston
# Processing record 77 of Set 6 | morehead
# Processing record 78 of Set 6 | amuntai
# Processing record 79 of Set 6 | vigeland
# Processing record 80 of Set 6 | casa nova
# Processing record 81 of Set 6 | naron
# Processing record 82 of Set 6 | xuddur
# Processing record 83 of Set 6 | sainte-suzanne
# Processing record 84 of Set 6 | coquimbo
# Processing record 85 of Set 6 | sorong
# Processing record 86 of Set 6 | puerto maldonado
# Processing record 87 of Set 6 | kawalu
# Processing record 88 of Set 6 | turayf
# Processing record 89 of Set 6 | joshimath
# Processing record 90 of Set 6 | nueva helvecia
# Processing record 91 of Set 6 | kungurtug
# Processing record 92 of Set 6 | santa cruz del sur
# Processing record 93 of Set 6 | san jeronimo
# Processing record 94 of Set 6 | iseyin
# Processing record 95 of Set 6 | pisco
# Processing record 96 of Set 6 | belyye berega
# Processing record 97 of Set 6 | chicama
# Processing record 98 of Set 6 | santa eulalia del rio
# City santa eulalia del rio not found. Skipping..............
# Processing record 99 of Set 6 | davila
# Processing record 100 of Set 6 | daru
# Processing record 1 of Set 7 | panguna
# Processing record 2 of Set 7 | lubango
# Processing record 3 of Set 7 | roros
# Processing record 4 of Set 7 | mossendjo
# Processing record 5 of Set 7 | aurillac
# Processing record 6 of Set 7 | peniche
# Processing record 7 of Set 7 | port-cartier
# Processing record 8 of Set 7 | yaan
# Processing record 9 of Set 7 | port lavaca
# Processing record 10 of Set 7 | lasa
# Processing record 11 of Set 7 | brae
# Processing record 12 of Set 7 | mandan
# Processing record 13 of Set 7 | priego de cordoba
# Processing record 14 of Set 7 | nautanwa
# Processing record 15 of Set 7 | bur gabo
# City bur gabo not found. Skipping..............
# Processing record 16 of Set 7 | cam ranh
# Processing record 17 of Set 7 | bubaque
# Processing record 18 of Set 7 | tamandare
# Processing record 19 of Set 7 | nipawin
# Processing record 20 of Set 7 | dolores
# Processing record 21 of Set 7 | petropavlovsk-kamchatskiy
# Processing record 22 of Set 7 | pontes e lacerda
# Processing record 23 of Set 7 | shihezi
# Processing record 24 of Set 7 | leeuwarden
# Processing record 25 of Set 7 | ozgon
# City ozgon not found. Skipping..............
# Processing record 26 of Set 7 | calama
# Processing record 27 of Set 7 | vestmanna
# Processing record 28 of Set 7 | bushehr
# Processing record 29 of Set 7 | abu dhabi
# Processing record 30 of Set 7 | tadine
# Processing record 31 of Set 7 | key largo
# Processing record 32 of Set 7 | ucluelet
# Processing record 33 of Set 7 | cap malheureux
# Processing record 34 of Set 7 | zhanaozen
# Processing record 35 of Set 7 | south venice
# Processing record 36 of Set 7 | ankazoabo
# Processing record 37 of Set 7 | matanzas
# Processing record 38 of Set 7 | krabi
# Processing record 39 of Set 7 | orlik
# Processing record 40 of Set 7 | huazolotitlan
# City huazolotitlan not found. Skipping..............
# Processing record 41 of Set 7 | kushiro
# Processing record 42 of Set 7 | edd
# Processing record 43 of Set 7 | pong
# Processing record 44 of Set 7 | parvatipuram
# Processing record 45 of Set 7 | labuan
# Processing record 46 of Set 7 | coahuayana
# Processing record 47 of Set 7 | san andres
# Processing record 48 of Set 7 | la ronge
# Processing record 49 of Set 7 | ponta do sol
# Processing record 50 of Set 7 | lac du bonnet
# Processing record 51 of Set 7 | azimur
# City azimur not found. Skipping..............
# Processing record 52 of Set 7 | nha trang
# Processing record 53 of Set 7 | bone
# Processing record 54 of Set 7 | camalu
# Processing record 55 of Set 7 | san luis obispo
# Processing record 56 of Set 7 | yar-sale
# Processing record 57 of Set 7 | bantry
# Processing record 58 of Set 7 | salamiyah
# Processing record 59 of Set 7 | la fleche
# Processing record 60 of Set 7 | sinazongwe
# Processing record 61 of Set 7 | chokwe
# Processing record 62 of Set 7 | miastko
# Processing record 63 of Set 7 | mecca
# Processing record 64 of Set 7 | aksu
# Processing record 65 of Set 7 | sungaipenuh
# Processing record 66 of Set 7 | laurel
# Processing record 67 of Set 7 | nanakuli
# Processing record 68 of Set 7 | yefira
# City yefira not found. Skipping..............
# Processing record 69 of Set 7 | mtwara
# Processing record 70 of Set 7 | luanda
# Processing record 71 of Set 7 | hamilton
# Processing record 72 of Set 7 | yumen
# Processing record 73 of Set 7 | kalininsk
# Processing record 74 of Set 7 | kayfan
# City kayfan not found. Skipping..............
# Processing record 75 of Set 7 | nyagan
# Processing record 76 of Set 7 | iralaya
# Processing record 77 of Set 7 | djambala
# Processing record 78 of Set 7 | qasigiannguit
# Processing record 79 of Set 7 | karamea
# City karamea not found. Skipping..............
# Processing record 80 of Set 7 | boa vista
# Processing record 81 of Set 7 | perivolion
# Processing record 82 of Set 7 | lashio
# Processing record 83 of Set 7 | itaobim
# Processing record 84 of Set 7 | kota belud
# Processing record 85 of Set 7 | ayan
# Processing record 86 of Set 7 | ifo
# Processing record 87 of Set 7 | lata
# Processing record 88 of Set 7 | tazovskiy
# Processing record 89 of Set 7 | harper
# Processing record 90 of Set 7 | jizan
# Processing record 91 of Set 7 | ban nahin
# Processing record 92 of Set 7 | northport
# Processing record 93 of Set 7 | aktash
# Processing record 94 of Set 7 | barranca
# Processing record 95 of Set 7 | itahari
# City itahari not found. Skipping..............
# Processing record 96 of Set 7 | sobolevo
# Processing record 97 of Set 7 | tugolesskiy bor
# Processing record 98 of Set 7 | broadford
# Processing record 99 of Set 7 | trezzo
# City trezzo not found. Skipping..............
# Processing record 100 of Set 7 | faro
# Processing record 1 of Set 8 | puerto rico
# Processing record 2 of Set 8 | fevralsk
# City fevralsk not found. Skipping..............
# Processing record 3 of Set 8 | wadi maliz
# Processing record 4 of Set 8 | aberfeldy
# Processing record 5 of Set 8 | rivadavia
# Processing record 6 of Set 8 | coos bay
# Processing record 7 of Set 8 | sagone
# Processing record 8 of Set 8 | pacific grove
# Processing record 9 of Set 8 | ofunato
# Processing record 10 of Set 8 | pottsville
# Processing record 11 of Set 8 | raudeberg
# Processing record 12 of Set 8 | lydenburg
# Processing record 13 of Set 8 | santo domingo
# Processing record 14 of Set 8 | jamuria
# Processing record 15 of Set 8 | jeremie
# Processing record 16 of Set 8 | mahon
# Processing record 17 of Set 8 | hearst
# Processing record 18 of Set 8 | zhaotong
# Processing record 19 of Set 8 | richards bay
# Processing record 20 of Set 8 | quatre cocos
# Processing record 21 of Set 8 | harrisonburg
# Processing record 22 of Set 8 | ambilobe
# Processing record 23 of Set 8 | bereda
# Processing record 24 of Set 8 | sioux lookout
# Processing record 25 of Set 8 | dezhou
# Processing record 26 of Set 8 | moscow
# Processing record 27 of Set 8 | molina
# Processing record 28 of Set 8 | kuytun
# Processing record 29 of Set 8 | kishi
# Processing record 30 of Set 8 | hovd
# Processing record 31 of Set 8 | la macarena
# Processing record 32 of Set 8 | medea
# Processing record 33 of Set 8 | svetlogorsk
# Processing record 34 of Set 8 | ziro
# Processing record 35 of Set 8 | foumban
# Processing record 36 of Set 8 | makakilo city
# Processing record 37 of Set 8 | mumford
# Processing record 38 of Set 8 | mitu
# Processing record 39 of Set 8 | jobabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert city data to a dataframe
city_data_df = pd.DataFrame(city_data)

# %%
# Re-order the columns
new_order = ['City', 'Country', 'Lat', 'Lng',
             'Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.60  -73.97     48.00       100          20
# 1         Mao      ES  39.89    4.27     68.00        82          40
# 2  Butaritari      KI   3.07  172.79     81.57        64          47
# 3  Nanortalik      GL  60.14  -45.24     29.66        98         100
# 4    Cherskiy      RU  68.75  161.30      6.76        95          99
#
#    Wind Speed Current Description
# 0        3.36                 fog
# 1        5.82    scattered clouds
# 2        5.64    scattered clouds
# 3       17.00     overcast clouds
# 4        4.54          light snow

# %%
# Exporting the dataframe to a csv file
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv.csv', index_label='City_ID')
